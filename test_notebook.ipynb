# %%
import pandas as pd

df = pd.read_csv("tabular_data\listing.csv")

# %%
import missingno as msno
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
df = df.dropna(subset=["Cleanliness_rating", "Accuracy_rating", "Communication_rating", "Location_rating", "Check-in_rating", "Value_rating"])
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
df = df.dropna(subset=["Description"])
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
from tabular_data import DataPreparation


dataprep = DataPreparation()  

dataprep.remove_rows_with_missing_ratings()
# Out:
#                                       ID    Category  \
# 0   f9dcbd09-32ac-41d9-a0b1-fdb2793378cf  Treehouses
# 1   1b4736a7-e73e-45bc-a9b5-d3e7fcf652fd  Treehouses
# 2   d577bc30-2222-4bef-a35e-a9825642aec4  Treehouses
# 3   ca9cbfd4-7798-4e8d-8c17-d5a64fba0abc  Treehouses
# 4   8b2d0f78-16d8-4559-8692-62ebce2a1302  Treehouses
# 5   cfe479b9-c8f8-44af-9bc6-46ede9f14bb5  Treehouses
# 6   93b1bfb4-67e7-4d70-9d84-b5e24f820d8c  Treehouses
# 7   9033002f-5ff2-45df-af91-ef1594ac353f  Treehouses
# 8   59705407-dc9b-444f-b0b0-afc472ca7c7f  Treehouses
# 9   3f063cb3-b39c-46ce-b417-059e71a6beb9  Treehouses
# 10  36dc1670-02ae-483b-9384-9261cc0f5abe  Treehouses
# 11  1e304e46-bf16-4ad4-9a94-844346a8c61e  Treehouses
#
#                                                Title  \
# 0                  Red Kite Tree Tent - Ynys Affalon
# 1     Az Alom Cabin - Treehouse Tree to Nature Cabin
# 2                        Cabane Entre Les Pins\n🌲🏕️🌲
# 3   Tree Top Cabin with log burner & private hot tub
# ...

# %%
from ast import literal_eval

print('type before lteral_eval...')
print(type(df['Description'][0]))

for item in range(len(df["Description"])):
            df["Description"][item] = literal_eval(df["Description"][item]) 

print('type after lteral_eval...')
print(type(df['Description'][0]))
# Out:
# type before lteral_eval...
# <class 'list'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18044/368645108.py in <module>
#       5
#       6 for item in range(len(df["Description"])):
# ----> 7             df["Description"][item] = literal_eval(df["Description"][item])
#       8
#       9 print('type after lteral_eval...')
#
# c:\Users\amyma\anaconda3\lib\ast.py in literal_eval(node_or_string)
#     103                     return left - right
#     104         return _convert_signed_num(node)
# --> 105     return _convert(node_or_string)
#     106
#     107
#
# c:\Users\amyma\anaconda3\lib\ast.py in _convert(node)
#     102                 else:
#     103                     return left - right
# --> 104         return _convert_signed_num(node)
#     105     return _convert(node_or_string)
#     106
#
# ...

# %%
print(df['Description'][0])
# Out:
# ['About this space', "Escape to one of these two fabulous Tree Tents. Suspended high above the canopy, it’s time to appreciate life from a new perspective. Featured on George Clarke’s Amazing Spaces, these Tree Tents are a feat of aviation technology. Tree Tent comes complete with fire pit, outdoor kitchen and shower with hot water. You’ll discover a comfortable bed and cosy wood burning stove. Part of the Red Kite Estate, along with our barn and its sister tree tent, the first ever built in the UK, Dragon's Egg.", 'The space', 'The space\nThe true joy of this place is how wonderfully simple it is (aviation technology aside). Days are filled with fireside discussions, wildlife watching and stunningly beautiful walks. With the nearest mobile signal a ten minute walk away, it’s a great place to ditch the digital and truly escape. Head over the bridge to your own private deck that happily houses a clever outdoor-kitchen and shower (complete with hot water). It’s the perfect spot to fry 
# ...

# %%
df = df.dropna(subset=['Description'])
print(df['Description'][0])
# Out:
# ['About this space', "Escape to one of these two fabulous Tree Tents. Suspended high above the canopy, it’s time to appreciate life from a new perspective. Featured on George Clarke’s Amazing Spaces, these Tree Tents are a feat of aviation technology. Tree Tent comes complete with fire pit, outdoor kitchen and shower with hot water. You’ll discover a comfortable bed and cosy wood burning stove. Part of the Red Kite Estate, along with our barn and its sister tree tent, the first ever built in the UK, Dragon's Egg.", 'The space', 'The space\nThe true joy of this place is how wonderfully simple it is (aviation technology aside). Days are filled with fireside discussions, wildlife watching and stunningly beautiful walks. With the nearest mobile signal a ten minute walk away, it’s a great place to ditch the digital and truly escape. Head over the bridge to your own private deck that happily houses a clever outdoor-kitchen and shower (complete with hot water). It’s the perfect spot to fry 
# ...

# %%
new_list = list(filter(lambda x: x != ('About this space', ' ', " ", 'The space', 'Other things to note'), df['Description'][0]))

print(new_list)
# Out:
# ['About this space', "Escape to one of these two fabulous Tree Tents. Suspended high above the canopy, it’s time to appreciate life from a new perspective. Featured on George Clarke’s Amazing Spaces, these Tree Tents are a feat of aviation technology. Tree Tent comes complete with fire pit, outdoor kitchen and shower with hot water. You’ll discover a comfortable bed and cosy wood burning stove. Part of the Red Kite Estate, along with our barn and its sister tree tent, the first ever built in the UK, Dragon's Egg.", 'The space', 'The space\nThe true joy of this place is how wonderfully simple it is (aviation technology aside). Days are filled with fireside discussions, wildlife watching and stunningly beautiful walks. With the nearest mobile signal a ten minute walk away, it’s a great place to ditch the digital and truly escape. Head over the bridge to your own private deck that happily houses a clever outdoor-kitchen and shower (complete with hot water). It’s the perfect spot to fry 
# ...

# %%
new_list = list(filter(lambda x: x != 'About this space', df['Description'][0]))


print(new_list)
# Out:
# ["Escape to one of these two fabulous Tree Tents. Suspended high above the canopy, it’s time to appreciate life from a new perspective. Featured on George Clarke’s Amazing Spaces, these Tree Tents are a feat of aviation technology. Tree Tent comes complete with fire pit, outdoor kitchen and shower with hot water. You’ll discover a comfortable bed and cosy wood burning stove. Part of the Red Kite Estate, along with our barn and its sister tree tent, the first ever built in the UK, Dragon's Egg.", 'The space', 'The space\nThe true joy of this place is how wonderfully simple it is (aviation technology aside). Days are filled with fireside discussions, wildlife watching and stunningly beautiful walks. With the nearest mobile signal a ten minute walk away, it’s a great place to ditch the digital and truly escape. Head over the bridge to your own private deck that happily houses a clever outdoor-kitchen and shower (complete with hot water). It’s the perfect spot to fry up breakfast whilst 
# ...

# %%
#one option
        #change string to list
        for item in range(len(self.df["Description"])):
            self.df["Description"][item] = literal_eval(self.df["Description"][item]) 
        
        #join the list elements
        for item, description in enumerate(self.df["Description"]):
            for description_index, description_element in enumerate(description):
                if description_element in ["About this space", 
                                            "The space", 
                                            "Guest access", 
                                            "Other things to note",
                                            "",
                                            " "
                                            ]:
                    self.df["Description"][item].pop(description_index)

# %%
from ast import literal_eval

try:
    cleaned_x = literal_eval(df['Description'][0])
    cleaned_x.remove("About this space")
    cleaned_x = "".join(cleaned_x)
    return cleaned_x
except Exception as e:
    
    return x
